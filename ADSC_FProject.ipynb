# %% [markdown]
# # Segmenting And Clustering Neighbourhoods Project

# %% [markdown]
# _This notebooks is used for the project within the Courser course 'Applied Data Science Capstone'_

# %% [markdown]
# ## The Project Goals

# %% [markdown]
# We are going to develop an application that will help families with kids to plan their day-off. <br/>
# In big cities, such as Moscow, there are thousands of venues that could be interesting for kids. But unfortunately their parents do not know about them. In fact, there is a very limited list of places affordable for kids, mostly placed in the center of the city, that are well known to everybody. They are nice but always overcrowded and it could take more than an hour to get there through traffic jams. And parents encounter more problems when they are going to plan several activities for the same day. For example, where they could eat with kids, or what they will do if their plans, weather or mud  suddenly change.<br/>
# It would be nice to have an application that will show on the screen the clustered venues affordable for families with kids. That clusters could include venues for education and entertainment and highlight those that have been highly ranked by Foursquare users. And of course, it is very useful to see the clusters that are close to your living place, probably in your neighbourhood.

# %% [markdown]
# ## How To Determine Neighbourhoods in Moscow

# %% [markdown]
# There are several ways to determine neighbourhoods.<br/>
# The first one is by the municipalities. There are 12 administrative districts in Moscow that include 146 municipalities. Their boundaries can be downloaded at http://gis-lab.info/qa/moscow-atd.html in ESRI Shape, GeoJSON, CSV+VRT or KML formats.<br/>
# The second way is by the post offices locations. There are 13 post regions in Moscow that include 524 post offices. The geo locations of the post offices can be downloaded at http://hubofdata.ru/dataset/ruspost-msk in JSON format.

# %% [markdown]
# The first approach (by municipalities) seems to be more effective since it can provide wider point of view at neighbourhoods.<br/>
# At the same time using postoffices locations as neighbourhoods is easier since most venues have postcodes (except such as parks, playgrounds etc). For those that have not, it can be determined by the closest venues.

# %% [markdown]
# Почта России — это не орган власти, но госпредприятие часто критикуемое в виду качества работы. Данные по отделениям у них есть, в частности они публикуют их на нескольких своих сайтах основной из которых — это их сайт.
#
# Мы вытащили данные по их отделениям по Москве с информацией по координатам их нахождения, адресам, индексам, времени работы и так далее. Эти данные никак не удалось упаковать в CSV простым образом, так что они доступны цельным JSON файлом http://hubofdata.ru/dataset/ruspost-msk
#
# http://gis-lab.info/qa/moscow-atd.html
#
# http://geointellect.ru/ru-ru/Геоданные/Список-геоданных-по-Москве

# %% [markdown]
# Let's download the libraries we'll need

# %%
# !conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you run the cell for the first time or in case of error message "Name '...' is not defined"
import folium # map rendering library

# !conda install -c conda-forge geopy --yes # uncomment this line if you run the cell for the first time in case of error message "Name '...' is not defined"
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

import pandas as pd
import numpy as np
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2019.9.11  |       hecc5488_0         144 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     certifi-2019.9.11          |           py36_0         147 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     branca-0.3.1               |             py_0          25 KB  conda-forge
#     altair-3.2.0               |           py36_0         770 KB  conda-forge
#     openssl-1.1.1c             |       h516909a_0         2.1 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         3.3 MB
#
# The following NEW packages will be INSTALLED:
#
#     altair:          3.2.0-py36_0      conda-forge
#     branca:          0.3.1-py_0        conda-forge
#     folium:          0.5.0-py_0        conda-forge
#     vincent:         0.4.4-py_1        conda-forge
#
# The following packages will be UPDATED:
#
#     ca-certificates: 2019.5.15-1                   --> 2019.9.11-hecc5488_0 conda-forge
#     certifi:         2019.6.16-py36_1              --> 2019.9.11-py36_0     conda-forge
#
# The following packages will be DOWNGRADED:
#
#     openssl:         1.1.1d-h7b6447c_1             --> 1.1.1c-h516909a_0    conda-forge
#
#
# Downloading and Extracting Packages
# ca-certificates-2019 | 144 KB    | ##################################### | 100%
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# certifi-2019.9.11    | 147 KB    | ##################################### | 100%
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# branca-0.3.1         | 25 KB     | ##################################### | 100%
# altair-3.2.0         | 770 KB    | ##################################### | 100%
# openssl-1.1.1c       | 2.1 MB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     geopy-1.20.0               |             py_0          57 KB  conda-forge
#     geographiclib-1.49         |             py_0          32 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:          90 KB
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib: 1.49-py_0   conda-forge
#     geopy:         1.20.0-py_0 conda-forge
#
#
# Downloading and Extracting Packages
# geopy-1.20.0         | 57 KB     | ##################################### | 100%
# geographiclib-1.49   | 32 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %% [markdown]
# Let's download data for Moscow municipalities. The link is http://gis-lab.info/data/mos-adm/mo-csv.zip<br/>
# Since data are stored ind zip file we will need to unzip it first.

# %%
# importing required modules 
from zipfile import ZipFile 

# downloading zip file
# !wget -q -O 'mun_coordinates.zip' http://gis-lab.info/data/mos-adm/mo-csv.zip

# specifying the zip file name 
file_name = "mun_coordinates.zip"
  
# opening the zip file in READ mode 
with ZipFile(file_name, 'r') as zip: 
    # printing all the contents of the zip file 
    zip.printdir() 
  
    # extracting all the files 
    print('Extracting all the files now...') 
    zip.extractall() 
    print('Done!') 
    
print('Data downloaded!')
mun_coord = pd.read_csv('mo.csv')
# Out:
# File Name                                             Modified             Size
# mo.csv                                         2014-06-14 15:29:14       892686
# mo.csvt                                        2014-06-14 15:29:14           85
# mo.prj                                         2014-06-13 20:27:22          143
# mo.qml                                         2014-03-23 21:21:22        10368
# mo.vrt                                         2014-03-29 23:06:40          295
# Extracting all the files now...
# Done!
# Data downloaded!

# %% [markdown]
# Let's have a look at the data downloaded

# %%
mun_coord.head()
# Out:
#                                                  WKT             NAME  \
# 0  MULTIPOLYGON (((36.8031012 55.4408329,36.80319...         Киевский
# 1  POLYGON ((37.4276499 55.7482092,37.4284863 55....   Филёвский Парк
# 2  POLYGON ((36.8035692 55.4516224,36.8045117 55....  Новофёдоровское
# 3  POLYGON ((36.9372397 55.2413907,36.9372604 55....        Роговское
# 4  POLYGON ((37.4395575 55.6273129,37.4401803 55....     "Мосрентген"
#
#       OKATO     OKTMO         NAME_AO  OKATO_AO       ABBREV_AO  \
# 0  45298555  45945000        Троицкий  45298000        Троицкий
# 1  45268595  45328000        Западный  45268000             ЗАО
# 2  45298567  45954000        Троицкий  45298000        Троицкий
# 3  45298575  45956000        Троицкий  45298000        Троицкий
# 4  45297568  45953000  Новомосковский  45297000  Новомосковский
#
#                TYPE_MO
# 0            Поселение
# 1  Муниципальный округ
# 2            Поселение
# 3            Поселение
# 4            Поселение

# %% [markdown]
# It turned out that some columns have information in cyrillic. To make data more convinient for review within Coursera project we have to transliterate cyrillic symbols ito English ones the exact rules providing similar articulation.<br/>
# The cell below makes transliteration by replacing cyrillic symbols for the whole 'mo.csv' file.

# %%
import os
import fileinput

def latinizator(letter, dic):
    for i, j in dic.items():
        letter = letter.replace(i, j)
    return letter

legend = {
'а':'a',
'б':'b',
'в':'v',
'г':'g',
'д':'d',
'е':'e',
'ё':'yo',
'ж':'zh',
'з':'z',
'и':'i',
'й':'y',
'к':'k',
'л':'l',
'м':'m',
'н':'n',
'о':'o',
'п':'p',
'р':'r',
'с':'s',
'т':'t',
'у':'u',
'ф':'f',
'х':'h',
'ц':'ts',
'ч':'ch',
'ш':'sh',
'щ':'shch',
'ъ':'y',
'ы':'y',
'ь':"'",
'э':'e',
'ю':'yu',
'я':'ya',

'А':'A',
'Б':'B',
'В':'V',
'Г':'G',
'Д':'D',
'Е':'E',
'Ё':'Yo',
'Ж':'Zh',
'З':'Z',
'И':'I',
'Й':'Y',
'К':'K',
'Л':'L',
'М':'M',
'Н':'N',
'О':'O',
'П':'P',
'Р':'R',
'С':'S',
'Т':'T',
'У':'U',
'Ф':'F',
'Х':'H',
'Ц':'Ts',
'Ч':'Ch',
'Ш':'Sh',
'Щ':'Shch',
'Ъ':'Y',
'Ы':'Y',
'Ь':"'",
'Э':'E',
'Ю':'Yu',
'Я':'Ya',
}

with fileinput.FileInput('mo.csv', inplace=True, backup='.bak') as f:
    for line in f:
        print(latinizator(line, legend), end='')

# %% [markdown]
# Let's check the result.

# %%
mun_coord = pd.read_csv('mo.csv')
mun_coord.head()
# Out:
#                                                  WKT              NAME  \
# 0  MULTIPOLYGON (((36.8031012 55.4408329,36.80319...          Kievskiy
# 1  POLYGON ((37.4276499 55.7482092,37.4284863 55....   Filyovskiy Park
# 2  POLYGON ((36.8035692 55.4516224,36.8045117 55....  Novofyodorovskoe
# 3  POLYGON ((36.9372397 55.2413907,36.9372604 55....         Rogovskoe
# 4  POLYGON ((37.4395575 55.6273129,37.4401803 55....      "Mosrentgen"
#
#       OKATO     OKTMO         NAME_AO  OKATO_AO       ABBREV_AO  \
# 0  45298555  45945000       Troitskiy  45298000       Troitskiy
# 1  45268595  45328000        Zapadnyy  45268000             ZAO
# 2  45298567  45954000       Troitskiy  45298000       Troitskiy
# 3  45298575  45956000       Troitskiy  45298000       Troitskiy
# 4  45297568  45953000  Novomoskovskiy  45297000  Novomoskovskiy
#
#                 TYPE_MO
# 0             Poselenie
# 1  Munitsipal'nyy okrug
# 2             Poselenie
# 3             Poselenie
# 4             Poselenie

# %%
mun_coord.iat[0,0]
# Out:
# 'MULTIPOLYGON (((36.8031012 55.4408329,36.8031903 55.4416007,36.8035692 55.4516224,36.812528 55.4513994,36.8274471 55.4513398,36.8333688 55.4513764,36.8338034 55.4516439,36.8345763 55.4512558,36.8348594 55.4514247,36.8349932 55.4514931,36.8358013 55.4511173,36.8360591 55.4511632,36.8461554 55.4510412,36.8602864 55.4508946,36.8649423 55.4506415,36.8608407 55.4492656,36.8582649 55.4478456,36.8582898 55.447659,36.8600008 55.4466656,36.8611076 55.4473042,36.8622805 55.4467128,36.8638768 55.4472018,36.8694408 55.4489425,36.8724625 55.4502245,36.8749845 55.4513839,36.8773319 55.453135,36.8804877 55.4548177,36.8822676 55.455771,36.8833225 55.4551478,36.8837761 55.4554817,36.8846681 55.4551548,36.8855977 55.4548773,36.8863281 55.4552539,36.8952465 55.450465,36.8875942 55.4460139,36.8818703 55.4426547,36.8912361 55.437452,36.8915818 55.4377769,36.893413 55.4368788,36.8948019 55.4377928,36.8963369 55.4389852,36.8968637 55.4392912,36.8968237 55.4387451,36.8964101 55.4380589,36.8959156 55.4369562,36.8931806 55.4285387,36.8930385 55.4281378,36.892214 55.4255804,36.8920661 55.4251213,36.8921556 55.4250135,36.8929218 55.4250569,36.8939156 55.4236071,36.8938567 55.4229336,36.8931251 55.4224349,36.8916934 55.4211121,36.8919249 55.4163998,36.892068 55.4106145,36.892487 55.4102303,36.8953439 55.4078434,36.8974602 55.4060326,36.897289 55.4057843,36.8978411 55.4053155,36.9014402 55.402228,36.9016975 55.4019726,36.9016599 55.4018918,36.9037445 55.4002463,36.9042105 55.3993939,36.9042939 55.3991925,36.9043756 55.3989367,36.9046011 55.3984985,36.9049361 55.3978212,36.905001 55.3975771,36.9050214 55.3974678,36.9051339 55.3973911,36.9051533 55.3973512,36.9052789 55.3973497,36.9052676 55.3971375,36.9056722 55.3966414,36.9058245 55.392973,36.9057008 55.3921492,36.9057503 55.3910598,36.9057594 55.3908605,36.9057755 55.3906733,36.9058681 55.3896065,36.9056813 55.3894557,36.9059927 55.3892795,36.9060527 55.3891022,36.9060885 55.3889279,36.9064487 55.3884621,36.9070191 55.3877243,36.9072097 55.3875265,36.908038 55.3866655,36.9085849 55.3860978,36.9086165 55.3858614,36.9099096 55.3858468,36.9123641 55.385847,36.913446 55.3846883,36.9145318 55.3849421,36.9148241 55.3852584,36.9154068 55.385838,36.9148314 55.3859811,36.9144995 55.3864376,36.9144027 55.3866182,36.914388 55.3873263,36.9237377 55.3857522,36.9237051 55.3855538,36.9235417 55.3845608,36.9232996 55.3833698,36.92286 55.381672,36.9243451 55.3813831,36.9256639 55.3811944,36.9268142 55.3810358,36.9285658 55.3808373,36.9294326 55.3807241,36.9333296 55.3785258,36.9368952 55.3778962,36.9372385 55.3778355,36.9375251 55.3779406,36.9378493 55.3780886,36.9380218 55.378223,36.938135 55.378259,36.9383523 55.378264,36.9384511 55.378274,36.9387604 55.3784687,36.9389054 55.3784744,36.938998 55.3784883,36.9390912 55.3785209,36.939216 55.3786952,36.9393834 55.3787832,36.9395425 55.378815,36.9397523 55.3788012,36.9398512 55.3788038,36.9399508 55.3788363,36.9400467 55.3789325,36.9401388 55.3791223,36.9402611 55.3792293,36.9404404 55.3792797,36.9406203 55.3793451,36.9407605 55.379579,36.9408409 55.3796229,36.9409539 55.3796516,36.9412515 55.3797079,36.94148 55.3797464,36.9417081 55.3797849,36.9418876 55.3798389,36.9419976 55.3799723,36.9420574 55.3801699,36.9421094 55.3803303,36.9422175 55.3804038,36.9424643 55.3805094,36.9427682 55.3805469,36.9431181 55.3805878,36.9434391 55.3807373,36.9436847 55.3807979,36.9439298 55.3808476,36.9440911 55.3809429,36.9441597 55.3810245,36.9444425 55.3812943,36.9456781 55.3813769,36.9463375 55.3814214,36.9463628 55.3819338,36.9462919 55.3837501,36.9476495 55.3840183,36.9480387 55.3840585,36.9489448 55.383842,36.950458 55.3835148,36.9505983 55.3833953,36.9523564 55.3815177,36.9540126 55.3816732,36.9566428 55.3813449,36.9536141 55.3797706,36.953013 55.3762218,36.9564788 55.3734597,36.9637211 55.3678044,36.9612597 55.3641726,36.9640825 55.360593,36.9686263 55.3613102,36.9737167 55.3621136,36.9735128 55.3603249,36.9717514 55.3578985,36.9710819 55.3571299,36.9703153 55.3564,36.9700765 55.35484 ...

# %% [markdown]
# Now we are going to go through every polygon to find the maximum and minimum for longitude and latitude. Since we got data from .csv file polygon is a string.

# %%
# Python code to convert string to list with ',' as separator
def Convert(string): 
    li = list(string.split(",")) 
    return li 
  
# Driver code     
poly = Convert(mun_coord.iat[0,0])
for i in range(1,len(poly)):
    poly[i]

# %%
address = 'Moscow'

geolocator = Nominatim(user_agent="ny_explorer")
tor_location = geolocator.geocode(address)

tor_latitude = tor_location.latitude
tor_longitude =tor_location.longitude

print('The geograpical coordinate of Moscow are {}, {}.'.format(tor_latitude, tor_longitude))
# Out:
# The geograpical coordinate of Moscow are 55.7504461, 37.6174943.

# %%
# create map of Moscow using latitude and longitude values
map_moscow = folium.Map(location=[tor_latitude, tor_longitude], zoom_start=11)

# add markers to map
for lat, lng, borough, neighbourhood in zip(data2['Latitude'], data2['Longitude'], data2['Borough'], data2['Neighbourhood']):
    label = '{}, {}'.format(neighbourhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-d34b5831ef2b> in <module>
#       3
#       4 # add markers to map
# ----> 5 for lat, lng, borough, neighbourhood in zip(data2['Latitude'], data2['Longitude'], data2['Borough'], data2['Neighbourhood']):
#       6     label = '{}, {}'.format(neighbourhood, borough)
#       7     label = folium.Popup(label, parse_html=True)
#
# NameError: name 'data2' is not defined

# %%
CLIENT_ID = 'VC5VAI2CNSBEQ1BIWEREK0RDJX2VK4WVRYEXQTSLB4Q4XXFB' #  Foursquare ID
CLIENT_SECRET = 'HRGWOCZXY555UGMEUD4APX5LYXYTREVQNOLEQZJT1YFRW3U3' #  Foursquare Secret
VERSION = '20180605' # Foursquare API version. In fact, I didn't find the information about it on Foursquare site

print('The credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# The credentails:
# CLIENT_ID: VC5VAI2CNSBEQ1BIWEREK0RDJX2VK4WVRYEXQTSLB4Q4XXFB
# CLIENT_SECRET:HRGWOCZXY555UGMEUD4APX5LYXYTREVQNOLEQZJT1YFRW3U3

# %% [markdown]
# Now let us clarify what venue categories we are interested in. To do so we can use the link https://developer.foursquare.com/docs/resources/categories that includes categories id.<br/>
# In fact, we are looking for:

# %% [markdown]
# Venue type | Catergory Id
# ---|---
# Parks | 4bf58dd8d48988d163941735
# Entertaiment centers | 4bf58dd8d48988d1e1931735
# Amusement parks | 4bf58dd8d48988d182941735
# Playgrounds | 4bf58dd8d48988d1e7941735
# Museums | 4bf58dd8d48988d181941735
# Cinema | 4bf58dd8d48988d17f941735
# Kids cafe | 4bf58dd8d48988d1d0941735

# %%
neighbourhood_latitude = tor_latitude
neighbourhood_longitude = tor_longitude
cat_id = '4bf58dd8d48988d163941735,4bf58dd8d48988d1e1931735,4bf58dd8d48988d182941735,4bf58dd8d48988d1e7941735,4bf58dd8d48988d181941735,4bf58dd8d48988d17f941735,4bf58dd8d48988d1d0941735' # id for Parks catergories

# %%
LIMIT = 100 # limit of number of venues returned by Foursquare API
radius = 1000 # define radius
# create URL
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&categoryId={}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    neighbourhood_latitude, 
    neighbourhood_longitude, 
    cat_id, 
    radius, 
    LIMIT)
url # display URL
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=VC5VAI2CNSBEQ1BIWEREK0RDJX2VK4WVRYEXQTSLB4Q4XXFB&client_secret=HRGWOCZXY555UGMEUD4APX5LYXYTREVQNOLEQZJT1YFRW3U3&v=20180605&ll=55.7504461,37.6174943&categoryId=4bf58dd8d48988d163941735,4bf58dd8d48988d1e1931735,4bf58dd8d48988d182941735,4bf58dd8d48988d1e7941735,4bf58dd8d48988d181941735,4bf58dd8d48988d17f941735,4bf58dd8d48988d1d0941735&radius=1000&limit=100'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5d891013bf7dde0038e175c9'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'}]},
#   'headerLocation': 'Khamovniki',
#   'headerFullLocation': 'Khamovniki, Moscow',
#   'headerLocationGranularity': 'neighborhood',
#   'query': 'park',
#   'totalResults': 59,
#   'suggestedBounds': {'ne': {'lat': 55.75944610900001,
#     'lng': 37.63345597204126},
#    'sw': {'lat': 55.741446090999986, 'lng': 37.60153262795873}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bf7fa734a67c928e27624cf',
#        'name': 'Aleksandrovskiy Garden (Александровский сад)',
#        'location': {'address': 'Манежная ул.',
#         'lat': 55.75270677200052,
#         'lng': 37.61373281478882,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 55.75270677200052,
#           'lng': 37.61373281478882}],
#         'distance': 344,
#         'postalCode': '119019',
#         'cc': 'RU',
#         'city': 'Москва',
#         'state': 'Москва',
#         'country': 'Россия',
#         'formattedAddress': ['Манежная ул.', '119019, Москва', 'Россия']},
#        'categories': [{'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'shortName': 'Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bf7fa734a67c928e27624cf-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ce5610e9bbf6ea8d605c8af',
#        'name': 'Дом Пашкова',
#        'location': {'address': 'Моховая ул., 3/5, стр. 1',
#         'crossStreet': 'ул. Знаменка',
#         'lat': 55.74975114575345,
#         'lng': 37.60845422744751,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 55.74975114575345,
#           'lng': 37.60845422744751}],
#         'distance': 571,
#         'cc': 'RU',
#         'city': 'Москва',
#         'state': 'Москва',
#         'country': 'Россия',
#         'formattedAddress': ['Моховая ул., 3/5, стр. 1 (ул. Знаменка)',
#          'Москва',
#          'Россия']},
#        'categories': [{'id': '4bf58dd8d48988d181941735',
#          'name': 'Museum',
#          'pluralName': 'Museums',
#          'shortName': 'Museum',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ce5610e9bbf6ea8d605c8af-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ee6374a9a52c1dadbece9f6',
#        'name': 'Zaryadye Park (Парк «Зарядье»)',
#        'location': {'address': 'Москворецкая наб.',
#         'crossStreet': 'ул. Варварка',
#         'lat': 55.750931611695684,
#         'lng': 37.6287317276001,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 55.750931611695684,
#           'lng': 37.6287317276001}],
#         'distance': 706,
#         'postalCode': '109012',
#         'cc': 'RU',
#         'neighborhood': 'Kitay-gorod',
#         'city': 'Москва',
#         'state': 'Москва',
#         'country': 'Россия',
#         'formattedAddress': ['Москворецкая наб. (ул. Варварка)',
#          '109012, Москва',
#          'Россия']},
#        'categories': [{'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'shortName': 'Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ee6374a9a52c1dadbece9f6-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57c69fb0498ee6139417c279',
#        'name': 'Ladurée',
#        'location': {'address': 'ГУМ',
#         'crossStreet': 'Красная пл., 3',
#         'lat': 55.7556216952892,
#         'lng': 37.620071549556165,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 55.7556216952892,
#           'lng': 37.620071549556165}],
#         'distance': 598,
#         'postalCode': '109012',
#         'cc': 'RU',
#         'neighborhood': 'Красная площадь',
#         'city': 'Москва',
#         'state': 'Москва',
#         'country': 'Россия',
#         'formattedAddress': ['ГУМ (Красная пл., 3)',
#          '109012, Москва',
#          'Россия']},
#        'categories': [{'id': '4bf58dd8d48988d1d0941735',
#          'name': 'Dessert Shop',
#          'pluralName': 'Dessert Shops',
#          'shortName': 'Desserts',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-57c69fb0498ee6139417c279-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c10f72781e976b089f00feb',
#        'name': 'Schusev State Museum of Architecture (Музей архитектуры им. А. В. Щусева)',
#        'location': {'address': 'ул. Воздвиженка, 5/25',
#         'crossStreet': 'Староваганьковский пер.',
#         'lat': 55.75246884331874,
#         'lng': 37.6072633266449,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 55.75246884331874,
#           'lng': 37.6072633266449}],
#         'distance': 679,
#         'postalCode': '119019',
#         'cc': 'RU',
#         'city': 'Москва',
#         'state': 'Москва',
#         'country': 'Россия',
#         'formattedAddress': ['ул. Воздвиженка, 5/25 (Староваганьковский пер.)',
#          '119019, Москва',
#          'Россия']},
#        'categories': [{'id': '4bf58dd8d48988d181941735',
#          'name': 'Museum',
#          'pluralName': 'Museums',
#          'shortName': 'Museum',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c10f72781e976b089f00feb-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c38b4b793db0f47e70d2292',
#        'name': 'Романов Синема',
#        'location': {'address': 'БЦ «Романов двор»',
#         'crossStreet': 'Романов пер., 4, стр. 2',
#         'lat': 55.754568,
#         'lng': 37.609577,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 55.754568,
#           'lng': 37.609577}],
#         'distance': 675,
#         'cc': 'RU',
#         'city': 'Москва',
#         'state': 'Москва',
#         'country': 'Россия',
#         'formattedAddress': ['БЦ «Романов двор» (Романов пер., 4, стр. 2)',
#          'Москва',
#          'Россия']},
#        'categories': [{'id': '4bf58dd8d48988d17f941735',
#          'name': 'Movie Theater',
#          'pluralName': 'Movie Theaters',
#          'shortName': 'Movie Theater',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/movietheater_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c38b4b793db0f47e70d2292-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c584f5a6201e21e695d4770',
#        'name': 'Репинский сквер',
#        'location': {'address': 'Болотная пл.',
#         'lat': 55.74524483044982,
#         'lng': 37.618324768349424,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 55.74524483044982,
#           'lng': 37.618324768349424}],
#         'distance': 581,
#         'cc': 'RU',
#         'city': 'Москва',
#         'state': 'Москва',
#         'country': 'Россия',
#         'formattedAddress': ['Болотная пл.', 'Москва', 'Россия']},
#        'categories': [{'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'shortName': 'Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c584f5a6201e21e695d4770-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5094fbdde4b087ea435d5c09',
#        'name': 'Музей книги / Museum of book',
#        'location': {'address': 'ул. Воздвиженка, 3/5',
#         'lat': 55.752221290286954,
#         'lng': 37.609076499938965,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 55.752221290286954,
#           'lng': 37.609076499938965}],
#         'distance': 563,
#         'cc': 'RU',
#         'city': 'Москва',
#         'state': 'Москва',
#         'country': 'Россия',
#         'formattedAddress': ['ул. Воздвиженка, 3/5', 'Москва', 'Россия']},
#        'categories': [{'id': '4bf58dd8d48988d181941735',
#          'name': 'Museum',
#          'pluralName': 'Museums',
#          'shortName': 'Museum',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5094fbdde4b087ea435d5c09-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '53735cbc498e64c3501c3803',
#        'name': 'Музеи Московского Кремля',
#        'location': {'address': 'Кремль',
#         'lat': 55.751789009887695,
#         'lng': 37.616476723476346,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 55.751789009887695,
#           'lng': 37.616476723476346}],
#         'distance': 162,
#         'postalCode': '103073',
#         'cc': 'RU',
#         'city': 'Москва',
#         'state': 'Москва',
#         'country': 'Россия',
#         'formattedAddress': ['Кремль', '103073, Москва', 'Россия']},
#        'categories': [{'id': '4bf58dd8d48988d190941735',
#          'name': 'History Museum',
#          'pluralName': 'History Museums',
#          'shortName': 'History Museum',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_history_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-53735cbc498e64c3501c3803-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ed7b0496da14054c3016e73',
#        'name': 'Кинозал ГУМ',
#        'location': {'address': 'ГУМ',
#         'crossStreet': 'Красная пл., 3',
#         'lat': 55.754805490704825,
#         'lng': 37.6218051190837,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 55.754805490704825,
#           'lng': 37.6218051190837}],
#         'distance': 555,
#         'postalCode': '109012',
#         'cc': 'RU',
#         'city': 'Москва',
#         'state': 'Москва',
#         'country': 'Россия',
#         'formattedAddress': ['ГУМ (Красная пл., 3)',
#          '109012, Москва',
#          'Россия']},
#        'categories': [{'id': '4bf58dd8d48988d180941735',
#          'name': 'Multiplex',
#          'pluralName': 'Multiplexes',
#          'shortName': 'Cineplex',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/movietheater_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ed7b0496da14054c3016e73-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c12731d1b5cef3b08c1edc4',
#        'name': "Lenin's Mausoleum (Мавзолей В. И. Ленина)",
#        'location': {'address': 'Красная пл.',
#         'lat': 55.75372653751348,
#         'lng': 37.61989653110504,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 55.75372653751348,
#           'lng': 37.61989653110504}],
#         'distance': 394,
#         'postalCode': '109012',
#         'cc': 'RU',
#         'city': 'Москва',
#         'state': 'Москва',
#         'country': 'Россия',
#         'formattedAddress': ['Красная пл.', '109012, Москва', 'Россия']},
#        'categories': [{'id': '4bf58dd8d48988d181941735',
#          'name': 'Museum',
#          'pluralName': 'Museums',
#          'shortName': 'Museum',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c12731d1b5cef3b08c1edc4-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bdbfff73904a593ed9a4c9e',
#        'name': 'Kremlin Armory (Оружейная палата)',
#        'location': {'address': 'Московский Кремль',
#         'lat': 55.74938922748553,
#         'lng': 37.613328784627306,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 55.74938922748553,
#           'lng': 37.613328784627306}],
#         'distance': 286,
#         'postalCode': '103073',
#         'cc': 'RU',
#         'city': 'Москва',
#         'state': 'Москва',
#         'country': 'Россия',
#         'formattedAddress': ['Московский Кремль', '103073, Москва', 'Россия']},
#        'categories': [{'id': '4bf58dd8d48988d190941735',
#          'name': 'History Museum',
#          'pluralName': 'History Museums',
#          'shortName': 'History Museum',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_history_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bdbfff73904a593ed9a4c9e-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bfbb199565f76b04ccf05db',
#        'name': 'The Kremlin (Кремль)',
#        'location': {'address': 'Красная пл.',
#         'lat': 55.751999,
#         'lng': 37.617734,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 55.751999,
#           'lng': 37.617734}],
#         'distance': 173,
#         'postalCode': '101000',
#         'cc': 'RU',
#         'city': 'Москва',
#         'state': 'Москва',
#         'country': 'Россия',
#         'formattedAddress': ['Красная пл.', '101000, Москва', 'Россия']},
#        'categories': [{'id': '4bf58dd8d48988d126941735',
#          'name': 'Government Building',
#          'pluralName': 'Government Buildings',
#          'shortName': 'Government',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/government_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bfbb199565f76b04ccf05db-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51bb789f498ec3fd095a9e89',
#        'name': 'Сквер Строителей Москвы',
#        'location': {'address': 'Большая Никитская ул., 7/10',
#         'lat': 55.755868,
#         'lng': 37.607522,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 55.755868,
#           'lng': 37.607522}],
#         'distance': 868,
#         'cc': 'RU',
#         'city': 'Москва',
#         'state': 'Москва',
#         'country': 'Россия',
#         'formattedAddress': ['Большая Никитская ул., 7/10',
#          'Москва',
#          'Россия']},
#        'categories': [{'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'shortName': 'Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-51bb789f498ec3fd095a9e89-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4db2e43b93a017099db6857f',
#        'name': 'Микросквер с бюстом Фрунзе',
#        'location': {'address': 'ул. Знаменка',
#         'crossStreet': 'Крестовоздвиженский пер.',
#         'lat': 55.75033866435288,
#         'lng': 37.60478022755693,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 55.75033866435288,
#           'lng': 37.60478022755693}],
#         'distance': 796,
#         'cc': 'RU',
#         'city': 'Москва',
#         'state': 'Москва',
#         'country': 'Россия',
#         'formattedAddress': ['ул. Знаменка (Крестовоздвиженский пер.)',
#          'Москва',
#          'Россия']},
#        'categories': [{'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'shortName': 'Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4db2e43b93a017099db6857f-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e2ed785d22daa76ed8fe1e4',
#        'name': 'Дворик Дома на набережной',
#        'location': {'address': 'Дом на набережной',
#         'crossStreet': 'ул. Серафимовича, 2',
#         'lat': 55.74377920477061,
#         'lng': 37.61349018637704,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 55.74377920477061,
#           'lng': 37.61349018637704}],
#         'distance': 783,
#         'cc': 'RU',
#         'city': 'Москва',
#         'state': 'Москва',
#         'country': 'Россия',
#         'formattedAddress': ['Дом на набережной (ул. Серафимовича, 2)',
#          'Москва',
#          'Россия']},
#        'categories': [{'id': '4bf58dd8d48988d1e7941735',
#          'name': 'Playground',
#          'pluralName': 'Playgrounds',
#          'shortName': 'Playground',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/playground_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e2ed785d22daa76ed8fe1e4-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4dda4395d4c05d50972bf5c5',
#        'name': 'Парк Храма Христа Спасителя',
#        'location': {'address': 'ул. Волхонка, 15',
#         'lat': 55.74543655589466,
#         'lng': 37.60624408721924,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 55.74543655589466,
#           'lng': 37.60624408721924}],
#         'distance': 898,
#         'cc': 'RU',
#         'city': 'Москва',
#         'state': 'Москва',
#         'country': 'Россия',
#         'formattedAddress': ['ул. Волхонка, 15', 'Москва', 'Россия']},
#        'categories': [{'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'shortName': 'Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4dda4395d4c05d50972bf5c5-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '52e77cdd498e7c6e1d68d7aa',
#        'name': 'Paul',
#        'location': {'address': 'Романов пер., 2/6, стр. 7',
#         'lat': 55.75413648337817,
#         'lng': 37.60998576879501,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 55.75413648337817,
#           'lng': 37.60998576879501}],
#         'distance': 624,
#         'cc': 'RU',
#         'neighborhood': 'Охотный ряд',
#         'city': 'Москва',
#         'state': 'Москва',
#         'country': 'Россия',
#         'formattedAddress': ['Романов пер., 2/6, стр. 7', 'Москва', 'Россия']},
#        'categories': [{'id': '4bf58dd8d48988d1d0941735',
#          'name': 'Dessert Shop',
#          'pluralName': 'Dessert Shops',
#          'shortName': 'Desserts',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-52e77cdd498e7c6e1d68d7aa-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5999755dee628b267da4ae65',
#        'name': 'Ladurée',
#        'location': {'address': 'Никольская ул., 5/1, стр. 3',
#         'lat': 55.75562175615289,
#         'lng': 37.619935309543806,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 55.75562175615289,
#           'lng': 37.619935309543806}],
#         'distance': 596,
#         'postalCode': '109012',
#         'cc': 'RU',
#         'city': 'Москва',
#         'state': 'Москва',
#         'country': 'Россия',
#         'formattedAddress': ['Никольская ул., 5/1, стр. 3',
#          '109012, Москва',
#          'Россия']},
#        'categories': [{'id': '4bf58dd8d48988d1d0941735',
#          'name': 'Dessert Shop',
#          'pluralName': 'Dessert Shops',
#          'shortName': 'Desserts',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5999755dee628b267da4ae65-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d77379d926a6dcb704b4500',
#        'name': 'Diamond Fund (Алмазный фонд)',
#        'location': {'address': 'Боровицкая ул.',
#         'lat': 55.749367713068764,
#         'lng': 37.61312127113342,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 55.749367713068764,
#           'lng': 37.61312127113342}],
#         'distance': 299,
#         'postalCode': '119072',
#         'cc': 'RU',
#         'city': 'Москва',
#         'state': 'Москва',
#         'country': 'Россия',
#         'formattedAddress': ['Боровицкая ул.', '119072, Москва', 'Россия']},
#        'categories': [{'id': '4bf58dd8d48988d190941735',
#          'name': 'History Museum',
#          'pluralName': 'History Museums',
#          'shortName': 'History Museum',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_history_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d77379d926a6dcb704b4500-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5362204c498ef2cd20eb5c44',
#        'name': 'Выставочный павильон «Зарядье»',
#        'location': {'address': 'ул. Варварка, 6',
#         'lat': 55.75146296066621,
#         'lng': 37.62596368789673,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 55.75146296066621,
#           'lng': 37.62596368789673}],
#         'distance': 542,
#         'cc': 'RU',
#         'city': 'Москва',
#         'state': 'Москва',
#         'country': 'Россия',
#         'formattedAddress': ['ул. Варварка, 6', 'Москва', 'Россия']},
#        'categories': [{'id': '4bf58dd8d48988d181941735',
#          'name': 'Museum',
#          'pluralName': 'Museums',
#          'shortName': 'Museum',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5362204c498ef2cd20eb5c44-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '54facc98498e07def48a0889',
#        'name': 'ARTFLECTION',
#        'location': {'lat': 55.75848121410953,
#         'lng': 37.61055499068378,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 55.75848121410953,
#           'lng': 37.61055499068378}],
#         'distance': 994,
#         'cc': 'RU',
#         'country': 'Россия',
#         'formattedAddress': ['Россия']},
#        'categories': [{'id': '4bf58dd8d48988d181941735',
#          'name': 'Museum',
#          'pluralName': 'Museums',
#          'shortName': 'Museum',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-54facc98498e07def48a0889-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '54493ae4498e1cf931d69630',
#        'name': 'Кинотеатр «Москва»',
#        'location': {'address': 'ТГ «Модный сезон»',
#         'crossStreet': 'ул. Охотный Ряд, 2',
#         'lat': 55.757882913138424,
#         'lng': 37.61837852124373,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 55.757882913138424,
#           'lng': 37.61837852124373}],
#         'distance': 829,
#         'postalCode': '109012',
#         'cc': 'RU',
#         'city': 'Москва',
#         'state': 'Москва',
#         'country': 'Россия',
#         'formattedAddress': ['ТГ «Модный сезон» (ул. Охотный Ряд, 2)',
#          '109012, Москва',
#          'Россия']},
#        'categories': [{'id': '4bf58dd8d48988d180941735',
#          'name': 'Multiplex',
#          'pluralName': 'Multiplexes',
#          'shortName': 'Cineplex',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/movietheater_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-54493ae4498e1cf931d69630-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bee5d152c082d7f2b5d3042',
#        'name': "St. Basil's Cathedral (Храм Василия Блаженного)",
#        'location': {'address': 'Красная пл.',
#         'crossStreet': 'пл. Васильевский Спуск',
#         'lat': 55.75252441045641,
#         'lng': 37.62310981750488,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 55.75252441045641,
#           'lng': 37.62310981750488}],
#         'distance': 421,
#         'postalCode': '109012',
#         'cc': 'RU',
#         'city': 'Москва',
#         'state': 'Москва',
#         'country': 'Россия',
#         'formattedAddress': ['Красная пл. (пл. Васильевский Спуск)',
#          '109012, Москва',
#          'Россия']},
#        'categories': [{'id': '4bf58dd8d48988d132941735',
#          'name': 'Church',
#          'pluralName': 'Churches',
#          'shortName': 'Church',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/religious_church_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bee5d152c082d7f2b5d3042-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ba4b8def964a52024af38e3',
#        'name': 'The State Historical Museum (Государственный исторический музей)',
#        'location': {'address': 'Красная пл., 1',
#         'crossStreet': 'пр. Воскресенские Ворота',
#         'lat': 55.755330683812694,
#         'lng': 37.61776685714721,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 55.755330683812694,
#           'lng': 37.61776685714721}],
#         'distance': 544,
#         'postalCode': '109012',
#         'cc': 'RU',
#         'neighborhood': 'Красная площадь',
#         'city': 'Москва',
#         'state': 'Москва',
#         'country': 'Россия',
#         'formattedAddress': ['Красная пл., 1 (пр. Воскресенские Ворота)',
#          '109012, Москва',
#          'Россия']},
#        'categories': [{'id': '4bf58dd8d48988d190941735',
#          'name': 'History Museum',
#          'pluralName': 'History Museums',
#          'shortName': 'History Museum',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_history_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ba4b8def964a52024af38e3-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5ae35cbdf5e9d70039ae6d6a',
#        'name': 'My Gelato',
#        'location': {'address': 'Манежная пл., 1, стр. 2',
#         'lat': 55.75464,
#         'lng': 37.613463,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 55.75464,
#           'lng': 37.613463}],
#         'distance': 530,
#         'postalCode': '119019',
#         'cc': 'RU',
#         'city': 'Москва',
#         'state': 'Москва',
#         'country': 'Россия',
#         'formattedAddress': ['Манежная пл., 1, стр. 2',
#          '119019, Москва',
#          'Россия']},
#        'categories': [{'id': '4bf58dd8d48988d1c9941735',
#          'name': 'Ice Cream Shop',
#          'pluralName': 'Ice Cream Shops',
#          'shortName': 'Ice Cream',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/icecream_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5ae35cbdf5e9d70039ae6d6a-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4fb8bb48e4b04abc0c176974',
#        'name': 'ГУМ-мороженое',
#        'location': {'address': 'ГУМ',
#         'crossStreet': 'Красная пл., 3',
#         'lat': 55.75509714848601,
#         'lng': 37.62026280216211,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 55.75509714848601,
#           'lng': 37.62026280216211}],
#         'distance': 546,
#         'cc': 'RU',
#         'city': 'Москва',
#         'state': 'Москва',
#         'country': 'Россия',
#         'formattedAddress': ['ГУМ (Красная пл., 3)', 'Москва', 'Россия']},
#        'categories': [{'id': '4bf58dd8d48988d1c9941735',
#          'name': 'Ice Cream Shop',
#          'pluralName': 'Ice Cream Shops',
#          'shortName': 'Ice Cream',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/icecream_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4fb8bb48e4b04abc0c176974-26'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ccd41a3ba0a548167784259',
#        'name': 'Успенская Звонница и Филаретова Пристройка',
#        'location': {'lat': 55.75086779775054,
#         'lng': 37.61759897528588,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 55.75086779775054,
#           'lng': 37.61759897528588}],
#         'distance': 47,
#         'cc': 'RU',
#         'city': 'Москва',
#         'state': 'Москва',
#         'country': 'Россия',
#         'formattedAddress': ['Москва', 'Россия']},
#        'categories': [{'id': '4bf58dd8d48988d190941735',
#          'name': 'History Museum',
#          'pluralName': 'History Museums',
#          'shortName': 'History Museum',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_history_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ccd41a3ba0a548167784259-27'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '59c2277b0457b71b6308e821',
#        'name': 'Birch Grove (Березовая роща)',
#        'location': {'address': 'Парк «Зарядье»',
#         'crossStreet': 'Москворецкая ул.',
#         'lat': 55.75166946031868,
#         'lng': 37.62652426958084,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 55.75166946031868,
#           'lng': 37.62652426958084}],
#         'distance': 581,
#         'cc': 'RU',
#         'city': 'Москва',
#         'state': 'Москва',
#         'country': 'Россия',
#         'formattedAddress': ['Парк «Зарядье» (Москворецкая ул.)',
#          'Москва',
#          'Россия']},
#        'categories': [{'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'shortName': 'Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-59c2277b0457b71b6308e821-28'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5045f840e4b0ced4cec1e37d',
#        'name': 'Музей Отечественной войны 1812 года',
#        'location': {'address': 'пл. Революции, 2/3',
#         'lat': 55.75634740926401,
#         'lng': 37.618533968925476,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 55.75634740926401,
#           'lng': 37.618533968925476}],
#         'distance': 660,
#         'postalCode': '109012',
#         'cc': 'RU',
#         'city': 'Москва',
#         'state': 'Москва',
#         'country': 'Россия',
#         'formattedAddress': ['пл. Революции, 2/3',
#          '109012, Москва',
#          'Россия']},
#        'categories': [{'id': '4bf58dd8d48988d190941735',
#          'name': 'History Museum',
#          'pluralName': 'History Museums',
#          'shortName': 'History Museum',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_history_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5045f840e4b0ced4cec1e37d-29'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5ad4f3b94a1cc07b69b9d353',
#        'name': 'Внутренний Двор Библиотеки Им. Ленина',
#        'location': {'lat': 55.752219,
#         'lng': 37.608577,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 55.752219,
#           'lng': 37.608577}],
#         'distance': 592,
#         'postalCode': '119019',
#         'cc': 'RU',
#         'city': 'Москва',
#         'state': 'Москва',
#         'country': 'Россия',
#         'formattedAddress': ['119019, Москва', 'Россия']},
#        'categories': [{'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'shortName': 'Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5ad4f3b94a1cc07b69b9d353-30'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d6bd45db3e4a143499fea90',
#        'name': 'Территория 5D кино',
#        'location': {'address': 'ТЦ «Охотный ряд»',
#         'crossStreet': 'Манежная пл., 1, стр. 2',
#         'lat': 55.75621983780867,
#         'lng': 37.61548101910352,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 55.75621983780867,
#           'lng': 37.61548101910352}],
#         'distance': 654,
#         'postalCode': '125009',
#         'cc': 'RU',
#         'city': 'Москва',
#         'state': 'Москва',
#         'country': 'Россия',
#         'formattedAddress': ['ТЦ «Охотный ряд» (Манежная пл., 1, стр. 2)',
#          '125009, Москва',
#          'Россия']},
#        'categories': [{'id': '4bf58dd8d48988d17f941735',
#          'name': 'Movie Theater',
#          'pluralName': 'Movie Theaters',
#          'shortName': 'Movie Theater',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/movietheater_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d6bd45db3e4a143499fea90-31'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cfa2e1c7f2db1f78dd925d4',
#        'name': 'Old English Court (Старый английский двор)',
#        'location': {'address': 'ул. Варварка, 4а',
#         'lat': 55.752246885839355,
#         'lng': 37.6270055933842,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 55.752246885839355,
#           'lng': 37.6270055933842}],
#         'distance': 628,
#         'postalCode': '109012',
#         'cc': 'RU',
#         'city': 'Москва',
#         'state': 'Москва',
#         'country': 'Россия',
#         'formattedAddress': ['ул. Варварка, 4а', '109012, Москва', 'Россия']},
#        'categories': [{'id': '4bf58dd8d48988d190941735',
#          'name': 'History Museum',
#          'pluralName': 'History Museums',
#          'shortName': 'History Museum',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_history_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cfa2e1c7f2db1f78dd925d4-32'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f3e8fa7e4b0b8bcf2d51b66',
#        'name': 'Палаты бояр Романовых',
#        'location': {'address': 'ул. Варварка, 10',
#         'crossStreet': 'ул. Варварка, 10',
#         'lat': 55.752764,
#         'lng': 37.629179,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 55.752764,
#           'lng': 37.629179}],
#         'distance': 776,
#         'postalCode': '103012',
#         'cc': 'RU',
#         'city': 'Москва',
#         'state': 'Москва',
#         'country': 'Россия',
#         'formattedAddress': ['ул. Варварка, 10 (ул. Варварка, 10)',
#          '103012, Москва',
#          'Россия']},
#        'categories': [{'id': '4bf58dd8d48988d190941735',
#          'name': 'History Museum',
#          'pluralName': 'History Museums',
#          'shortName': 'History Museum',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_history_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f3e8fa7e4b0b8bcf2d51b66-33'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ccd4e9197d0224b198f65b8',
#        'name': 'Одностолпная палата Патриаршего дворца',
#        'location': {'address': 'Московский Кремль',
#         'lat': 55.75131200999014,
#         'lng': 37.616575956344604,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 55.75131200999014,
#           'lng': 37.616575956344604}],
#         'distance': 112,
#         'cc': 'RU',
#         'city': 'Москва',
#         'state': 'Москва',
#         'country': 'Россия',
#         'formattedAddress': ['Московский Кремль', 'Москва', 'Россия']},
#        'categories': [{'id': '4bf58dd8d48988d190941735',
#          'name': 'History Museum',
#          'pluralName': 'History Museums',
#          'shortName': 'History Museum',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_history_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ccd4e9197d0224b198f65b8-34'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ee7551fe4b04d23e3d76af5',
#        'name': 'Музей Большого Театра',
#        'location': {'crossStreet': 'Театральная Площадь',
#         'lat': 55.75850295760256,
#         'lng': 37.61849779818529,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 55.75850295760256,
#           'lng': 37.61849779818529}],
#         'distance': 899,
#         'cc': 'RU',
#         'city': 'Москва',
#         'state': 'Москва',
#         'country': 'Россия',
#         'formattedAddress': ['Театральная Площадь', 'Москва', 'Россия']},
#        'categories': [{'id': '4bf58dd8d48988d181941735',
#          'name': 'Museum',
#          'pluralName': 'Museums',
#          'shortName': 'Museum',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ee7551fe4b04d23e3d76af5-35'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5908b3eb35d3fc5e1c19a06e',
#        'name': 'Чистая линия',
#        'location': {'address': 'Тверская ул., 5/6',
#         'lat': 55.75814259777471,
#         'lng': 37.612880378776175,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 55.75814259777471,
#           'lng': 37.612880378776175}],
#         'distance': 904,
#         'postalCode': '125009',
#         'cc': 'RU',
#         'city': 'Москва',
#         'state': 'Москва',
#         'country': 'Россия',
#         'formattedAddress': ['Тверская ул., 5/6', '125009, Москва', 'Россия']},
#        'categories': [{'id': '4bf58dd8d48988d1c9941735',
#          'name': 'Ice Cream Shop',
#          'pluralName': 'Ice Cream Shops',
#          'shortName': 'Ice Cream',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/icecream_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5908b3eb35d3fc5e1c19a06e-36'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f896ef6e4b04a075e95c532',
#        'name': 'Музей «Дом на набережной»',
#        'location': {'address': 'ул. Серафимовича, 2',
#         'lat': 55.7451847120735,
#         'lng': 37.61203229427338,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 55.7451847120735,
#           'lng': 37.61203229427338}],
#         'distance': 678,
#         'postalCode': '119072',
#         'cc': 'RU',
#         'city': 'Москва',
#         'state': 'Москва',
#         'country': 'Россия',
#         'formattedAddress': ['ул. Серафимовича, 2',
#          '119072, Москва',
#          'Россия']},
#        'categories': [{'id': '4bf58dd8d48988d190941735',
#          'name': 'History Museum',
#          'pluralName': 'History Museums',
#          'shortName': 'History Museum',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_history_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f896ef6e4b04a075e95c532-37'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '53ae864e498ec5c31886662f',
#        'name': "Dippin' Dots",
#        'location': {'address': 'ТГ «Модный сезон»',
#         'crossStreet': 'ул. Охотный Ряд, 2',
#         'lat': 55.757015117583585,
#         'lng': 37.616459286941215,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 55.757015117583585,
#           'lng': 37.616459286941215}],
#         'distance': 734,
#         'cc': 'RU',
#         'city': 'Москва',
#         'state': 'Москва',
#         'country': 'Россия',
#         'formattedAddress': ['ТГ «Модный сезон» (ул. Охотный Ряд, 2)',
#          'Москва',
#          'Россия']},
#        'categories': [{'id': '4bf58dd8d48988d1c9941735',
#          'name': 'Ice Cream Shop',
#          'pluralName': 'Ice Cream Shops',
#          'shortName': 'Ice Cream',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/icecream_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-53ae864e498ec5c31886662f-38'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e9acfef4690c21335341e6f',
#        'name': 'Музей археологии Москвы',
#        'location': {'address': 'Манежная пл., 1а',
#         'lat': 55.75638240648581,
#         'lng': 37.6171875,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 55.75638240648581,
#           'lng': 37.6171875}],
#         'distance': 661,
#         'cc': 'RU',
#         'city': 'Москва',
#         'state': 'Москва',
#         'country': 'Россия',
#         'formattedAddress': ['Манежная пл., 1а', 'Москва', 'Россия']},
#        'categories': [{'id': '4bf58dd8d48988d190941735',
#          'name': 'History Museum',
#          'pluralName': 'History Museums',
#          'shortName': 'History Museum',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_history_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e9acfef4690c21335341e6f-39'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5457a18b498edf9b98e8773c',
#        'name': 'Artillery Courtyard (Артиллерийский двор)',
#        'location': {'address': 'Государственный исторический музей',
#         'crossStreet': 'Никольская ул., 5/1',
#         'lat': 55.75580103347015,
#         'lng': 37.61885583400726,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 55.75580103347015,
#           'lng': 37.61885583400726}],
#         'distance': 602,
#         'cc': 'RU',
#         'city': 'Москва',
#         'state': 'Москва',
#         'country': 'Россия',
#         'formattedAddress': ['Государственный исторический музей (Никольская ул., 5/1)',
#          'Москва',
#          'Россия']},
# ...
#          'shortName': 'Art Museum',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_art_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cee9a8e13aea143efac6e9f-45'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '536b943711d28e8a7640d02e',
#        'name': 'Греческий зал',
#        'location': {'address': 'ГМИИ им. А. С. Пушкина',
#         'crossStreet': 'ул. Волхонка, 12',
#         'lat': 55.74721131831652,
#         'lng': 37.60531329877492,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 55.74721131831652,
#           'lng': 37.60531329877492}],
#         'distance': 843,
#         'cc': 'RU',
#         'city': 'Москва',
#         'state': 'Москва',
#         'country': 'Россия',
#         'formattedAddress': ['ГМИИ им. А. С. Пушкина (ул. Волхонка, 12)',
#          'Москва',
#          'Россия']},
#        'categories': [{'id': '4bf58dd8d48988d18f941735',
#          'name': 'Art Museum',
#          'pluralName': 'Art Museums',
#          'shortName': 'Art Museum',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_art_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-536b943711d28e8a7640d02e-46'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51dfc211498e5c0fc34a68f6',
#        'name': 'Египетский зал',
#        'location': {'address': 'ГМИИ им. А. С. Пушкина',
#         'crossStreet': 'ул. Волхонка, 12',
#         'lat': 55.747258,
#         'lng': 37.605241,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 55.747258,
#           'lng': 37.605241}],
#         'distance': 845,
#         'cc': 'RU',
#         'city': 'Москва',
#         'state': 'Москва',
#         'country': 'Россия',
#         'formattedAddress': ['ГМИИ им. А. С. Пушкина (ул. Волхонка, 12)',
#          'Москва',
#          'Россия']},
#        'categories': [{'id': '4bf58dd8d48988d190941735',
#          'name': 'History Museum',
#          'pluralName': 'History Museums',
#          'shortName': 'History Museum',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_history_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-51dfc211498e5c0fc34a68f6-47'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d9053036174a093c875f0e3',
#        'name': 'Техническое здание ГМИИ им. А.С. Пушкина',
#        'location': {'address': 'Малый Знаменский пер., 8, стр. 1',
#         'crossStreet': 'между ул. Знаменка и Колымажным пер.',
#         'lat': 55.74872745672202,
#         'lng': 37.60575938580022,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 55.74872745672202,
#           'lng': 37.60575938580022}],
#         'distance': 759,
#         'postalCode': '119019',
#         'cc': 'RU',
#         'city': 'Москва',
#         'state': 'Москва',
#         'country': 'Россия',
#         'formattedAddress': ['Малый Знаменский пер., 8, стр. 1 (между ул. Знаменка и Колымажным пер.)',
#          '119019, Москва',
#          'Россия']},
#        'categories': [{'id': '4bf58dd8d48988d18f941735',
#          'name': 'Art Museum',
#          'pluralName': 'Art Museums',
#          'shortName': 'Art Museum',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_art_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d9053036174a093c875f0e3-48'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f8aba2ae4b0183206f81515',
#        'name': 'Дети — жертвы пороков взрослых',
#        'location': {'address': 'Болотная пл.',
#         'lat': 55.745906751546016,
#         'lng': 37.61934272348128,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 55.745906751546016,
#           'lng': 37.61934272348128}],
#         'distance': 518,
#         'cc': 'RU',
#         'city': 'Москва',
#         'state': 'Москва',
#         'country': 'Россия',
#         'formattedAddress': ['Болотная пл.', 'Москва', 'Россия']},
#        'categories': [{'id': '4bf58dd8d48988d12d941735',
#          'name': 'Monument / Landmark',
#          'pluralName': 'Monuments / Landmarks',
#          'shortName': 'Landmark',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/government_monument_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f8aba2ae4b0183206f81515-49'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d95cc027cfc1456c8e828f6',
#        'name': 'Международный фонд славянской письменности и культуры',
#        'location': {'address': 'Черниговский пер., 9/13, стр. 2',
#         'lat': 55.743650041285036,
#         'lng': 37.62592029097677,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 55.743650041285036,
#           'lng': 37.62592029097677}],
#         'distance': 922,
#         'postalCode': '127253',
#         'cc': 'RU',
#         'city': 'Москва',
#         'state': 'Москва',
#         'country': 'Россия',
#         'formattedAddress': ['Черниговский пер., 9/13, стр. 2',
#          '127253, Москва',
#          'Россия']},
#        'categories': [{'id': '4bf58dd8d48988d18f941735',
#          'name': 'Art Museum',
#          'pluralName': 'Art Museums',
#          'shortName': 'Art Museum',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_art_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d95cc027cfc1456c8e828f6-50'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e465b3b62845e1d3c8fdfd4',
#        'name': 'Геологический музей им. В. И. Вернадского',
#        'location': {'address': 'Моховая ул., 11, стр. 11',
#         'lat': 55.75599479399393,
#         'lng': 37.61272430419922,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 55.75599479399393,
#           'lng': 37.61272430419922}],
#         'distance': 686,
#         'postalCode': '125009',
#         'cc': 'RU',
#         'city': 'Москва',
#         'state': 'Москва',
#         'country': 'Россия',
#         'formattedAddress': ['Моховая ул., 11, стр. 11',
#          '125009, Москва',
#          'Россия']},
#        'categories': [{'id': '4bf58dd8d48988d191941735',
#          'name': 'Science Museum',
#          'pluralName': 'Science Museums',
#          'shortName': 'Science Museum',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_science_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '84217971'}},
#       'referralId': 'e-0-4e465b3b62845e1d3c8fdfd4-51'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '502e3f64e4b0543f988d8a64',
#        'name': 'Аптекарский приказ',
#        'location': {'address': 'Музей архитектуры им. А. В. Щусева',
#         'crossStreet': 'ул. Воздвиженка, 5',
#         'lat': 55.752151335485685,
#         'lng': 37.607644203356976,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 55.752151335485685,
#           'lng': 37.607644203356976}],
#         'distance': 645,
#         'postalCode': '101000',
#         'cc': 'RU',
#         'neighborhood': 'Arbat, Moscow',
#         'city': 'Москва',
#         'state': 'Москва',
#         'country': 'Россия',
#         'formattedAddress': ['Музей архитектуры им. А. В. Щусева (ул. Воздвиженка, 5)',
#          '101000, Москва',
#          'Россия']},
#        'categories': [{'id': '4bf58dd8d48988d1e2931735',
#          'name': 'Art Gallery',
#          'pluralName': 'Art Galleries',
#          'shortName': 'Art Gallery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/artgallery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-502e3f64e4b0543f988d8a64-52'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cd2a537158c54818c07b0e4',
#        'name': 'Зоологический музей',
#        'location': {'address': 'Большая Никитская ул., 2',
#         'lat': 55.755825748838824,
#         'lng': 37.60916233062744,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 55.755825748838824,
#           'lng': 37.60916233062744}],
#         'distance': 794,
#         'postalCode': '125009',
#         'cc': 'RU',
#         'neighborhood': 'Presnensky',
#         'city': 'Москва',
#         'state': 'Москва',
#         'country': 'Россия',
#         'formattedAddress': ['Большая Никитская ул., 2',
#          '125009, Москва',
#          'Россия']},
#        'categories': [{'id': '4bf58dd8d48988d191941735',
#          'name': 'Science Museum',
#          'pluralName': 'Science Museums',
#          'shortName': 'Science Museum',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_science_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cd2a537158c54818c07b0e4-53'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5b4777cecd441c002c8f2854',
#        'name': 'Soaring over Moscow (Полет над Москвой)',
#        'location': {'address': 'Медиацентр',
#         'crossStreet': 'ул. Варварка, 6',
#         'lat': 55.75149918874153,
#         'lng': 37.627143859863274,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 55.75149918874153,
#           'lng': 37.627143859863274}],
#         'distance': 615,
#         'cc': 'RU',
#         'city': 'Москва',
#         'state': 'Москва',
#         'country': 'Россия',
#         'formattedAddress': ['Медиацентр (ул. Варварка, 6)',
#          'Москва',
#          'Россия']},
#        'categories': [{'id': '5109983191d435c0d71c2bb1',
#          'name': 'Theme Park Ride / Attraction',
#          'pluralName': 'Theme Park Rides/Attractions',
#          'shortName': 'Theme Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/themepark_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5b4777cecd441c002c8f2854-54'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '572435df498ecb424cc3082f',
#        'name': 'Усадьба Голицыных',
#        'location': {'address': 'ул. Волхонка, 14, стр. 5',
#         'crossStreet': 'Малый Знаменский пер.',
#         'lat': 55.746492,
#         'lng': 37.604241,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 55.746492,
#           'lng': 37.604241}],
#         'distance': 939,
#         'cc': 'RU',
#         'city': 'Москва',
#         'state': 'Москва',
#         'country': 'Россия',
#         'formattedAddress': ['ул. Волхонка, 14, стр. 5 (Малый Знаменский пер.)',
#          'Москва',
#          'Россия']},
#        'categories': [{'id': '4bf58dd8d48988d18f941735',
#          'name': 'Art Museum',
#          'pluralName': 'Art Museums',
#          'shortName': 'Art Museum',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_art_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-572435df498ecb424cc3082f-55'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '52aefbe2498e45d024ebab4a',
#        'name': 'La Bublique Cafe',
#        'location': {'address': 'Романов пер, 4',
#         'lat': 55.75470320436584,
#         'lng': 37.609324106142886,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 55.75470320436584,
#           'lng': 37.609324106142886}],
#         'distance': 697,
#         'cc': 'RU',
#         'country': 'Россия',
#         'formattedAddress': ['Романов пер, 4', 'Россия']},
#        'categories': [{'id': '4bf58dd8d48988d1bc941735',
#          'name': 'Cupcake Shop',
#          'pluralName': 'Cupcake Shops',
#          'shortName': 'Cupcakes',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cupcakes_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-52aefbe2498e45d024ebab4a-56'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '542d1219498ee5493e0ef378',
#        'name': 'Tutti Frutti Frozen Yogurt',
#        'location': {'address': 'ТЦ «Охотный ряд»',
#         'crossStreet': 'Манежная пл., 1, стр. 2',
#         'lat': 55.75623748116575,
#         'lng': 37.61545152404054,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 55.75623748116575,
#           'lng': 37.61545152404054}],
#         'distance': 657,
#         'cc': 'RU',
#         'city': 'Москва',
#         'state': 'Москва',
#         'country': 'Россия',
#         'formattedAddress': ['ТЦ «Охотный ряд» (Манежная пл., 1, стр. 2)',
#          'Москва',
#          'Россия']},
#        'categories': [{'id': '512e7cae91d4cbb4e5efe0af',
#          'name': 'Frozen Yogurt Shop',
#          'pluralName': 'Frozen Yogurt Shops',
#          'shortName': 'Yogurt',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/frozenyogurt_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-542d1219498ee5493e0ef378-57'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5aa29bfe772fbc53116ad8b6',
#        'name': 'РастегаиКулебяка',
#        'location': {'address': 'ул. Варварка 6 ст3',
#         'lat': 55.750222,
#         'lng': 37.629375,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 55.750222,
#           'lng': 37.629375}],
#         'distance': 744,
#         'postalCode': '109012',
#         'cc': 'RU',
#         'city': 'Москва',
#         'state': 'Москва',
#         'country': 'Россия',
#         'formattedAddress': ['ул. Варварка 6 ст3',
#          '109012, Москва',
#          'Россия']},
#        'categories': [{'id': '52e81612bcbc57f1066b7a0a',
#          'name': 'Pie Shop',
#          'pluralName': 'Pie Shops',
#          'shortName': 'Pie Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pieshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5aa29bfe772fbc53116ad8b6-58'}]}]}}

# %%
#res = requests.get('https://api.foursquare.com/v2/venues/54a05990498e03eea5fcc08c').json()
#res
# Out:
#   File "<ipython-input-100-0eff7c77efda>", line 1
#     GET https://api.foursquare.com/v2/venues/54a05990498e03eea5fcc08c
#             ^
# SyntaxError: invalid syntax

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
venues = results['response']['groups'][0]['items']
    
nearby_venues = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.id','venue.name', 'venue.categories', 'reasons.items','venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]

# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues.iat[1,3]
# Out:
# [{'summary': 'This spot is popular',
#   'type': 'general',
#   'reasonName': 'globalInteractionReason'}]

# %%
nearby_venues.shape
# Out:
# (83, 6)

# %%
nearby_venues
# Out:
#                           id  \
# 0   53fb052c498eacc7b13ad60d
# 1   551bec5f498e82cfbfe296f6
# 2   5496fd26498e9c88a826633e
# 3   5623d6e5498efb95635afbf3
# 4   551320ca498e5fecfbb1c3d7
# 5   4f76d997e4b0d693688e74cd
# 6   53747d0d498e505d3e52b1fc
# 7   54a05990498e03eea5fcc08c
# 8   57a75275498eae176c62c14f
# 9   54a80c08498e18f46e788e28
# 10  4fe35feae4b05551e89089ac
# 11  57c69fb0498ee6139417c279
# 12  4c39ece63849c928ef02c2b1
# 13  52a2cc5a498ed6557219b9d9
# 14  59070c029746172d9d16f7f0
# 15  5482e29b498ee0762e589f90
# 16  54493ae4498e1cf931d69630
# 17  4dc583d0887717c880255254
# 18  4c7f5ef7a852199c5fa3ceaf
# 19  5b4e00d381a0ea002ccb39d7
# 20  55bf1aee498ed18b2d33a4ec
# 21  4ed7b0496da14054c3016e73
# 22  55858eb1498eef1e80ad54d9
# 23  57960fa9498eece389f422b3
# 24  532a904f498ef42e5b9997b3
# 25  522efa51498e5f18a66e81d3
# 26  5999755dee628b267da4ae65
# 27  4f52336de4b00615144859d8
# 28  4d5663f2fb65236a7be304b4
# 29  54089fde498ea14f6179715c
# ..                       ...
# 53  5a5b91bb35811b435b64b2bd
# 54  4d6bd45db3e4a143499fea90
# 55  51457074e4b0853bf143f4fb
# 56  4e0a0cd91838eb15af141307
# 57  5758391c498efe7dbef900d9
# 58  4bee5d152c082d7f2b5d3042
# 59  59c2277b0457b71b6308e821
# 60  4f30198cc2eed7907f75cb8f
# 61  4cfa2e1c7f2db1f78dd925d4
# 62  5908b3eb35d3fc5e1c19a06e
# 63  53ae864e498ec5c31886662f
# 64  4e9acfef4690c21335341e6f
# 65  53465ea2498e5a0d4d93c286
# 66  58d69a360802cb1557dee939
# 67  51694198498eb44b7eb082d6
# 68  5457a18b498edf9b98e8773c
# 69  50b78eb6e4b03e5877567655
# 70  5a477073898bdc16c10dcc23
# 71  556daba9498e68c8560ab504
# 72  4fbba192e4b009d97e0e59ab
# 73  5cdab1e24acb19002b81a2c1
# 74  5647660a498e15acb3db8c97
# 75  5197abc3498e42d10d304017
# 76  50ad0255e4b05efbd3352647
# 77  4d4ad43db480a1430a8a33ec
# 78  5b4777cecd441c002c8f2854
# 79  5039ef42e4b01bb806cf9244
# 80  542d1219498ee5493e0ef378
# 81  4ce91457e888f04d501d466b
# 82  4be299db2ff376b058314fed
#
#                                                  name  \
# 0                                             КидБург
# 1                                 Музей Детства в ЦДМ
# 2                                       Клаустрофобия
# 3                                        Формула кино
# 4                                      Шоу динозавров
# 5                Музей экслибриса и миниатюрной книги
# 6                   Café Vendome & Chocolate Boutique
# 7                                       Клаустрофобия
# 8                                    Нереальное место
# 9                                         Loft Cinema
# 10                                       Парк «Горка»
# 11                                            Ladurée
# 12                                    Ильинский сквер
# 13                               Сквер Майи Плисецкой
# 14                        Patisserie Francois Bodrero
# 15                   Квест в Реальности Теория Побега
# 16                                 Кинотеатр «Москва»
# 17                                Дворик Мандельштама
# 18                                  Дворик с фонтаном
# 19                                   Francois Bodrero
# 20                                          Teddy bar
# 21                                        Кинозал ГУМ
# 22                                  LOFT Ministerstvo
# 23                                      Клаустрофобия
# 24                                       Макс Бреннер
# 25                                    Сквер у Трубной
# 26                                            Ladurée
# 27            Кондитерская Клубничка центральный офис
# 28                                Музей «Огни Москвы»
# 29                                         Casa Leone
# ..                                                ...
# 53                                            Шарлима
# 54                                 Территория 5D кино
# 55                                     Вместе с мамой
# 56                                 Шахматная Скамейка
# 57                                       Лофт Авиатор
# 58    St. Basil's Cathedral (Храм Василия Блаженного)
# 59                       Birch Grove (Березовая роща)
# 60                                            Бон Пан
# 61         Old English Court (Старый английский двор)
# 62                                       Чистая линия
# 63                                       Dippin' Dots
# 64                            Музей археологии Москвы
# 65           Выставочный комплекс Исторического музея
# 66            Российское военно-историческое общество
# 67                        Палаты Сверчковых, XVII вв.
# 68          Artillery Courtyard (Артиллерийский двор)
# 69                           Московский Музей Дизайна
# 70                                      Flower Flavor
# 71                   Музей истории телефона Мастертел
# 72  Государственный Российский Дом народного творч...
# 73                                       Central Park
# 74                                   Upside Down Cake
# 75                           Внутренний двор Политеха
# 76                                              Chips
# 77                                    Rock'n'Roll Bar
# 78            Soaring over Moscow (Полет над Москвой)
# 79                                           Продукты
# 80                         Tutti Frutti Frozen Yogurt
# 81                                    Пироговая лавка
# 82                                             Пироги
#
#                       categories  \
# 0                         Arcade
# 1                         Museum
# 2                         Arcade
# 3                      Multiplex
# 4                     Theme Park
# 5                         Museum
# 6                   Dessert Shop
# 7                         Arcade
# 8                         Arcade
# 9                  Movie Theater
# 10                          Park
# 11                  Dessert Shop
# 12                          Park
# 13                          Park
# 14                  Dessert Shop
# 15                        Arcade
# 16                     Multiplex
# 17                          Park
# 18                          Park
# 19                  Dessert Shop
# 20                  Dessert Shop
# 21                     Multiplex
# 22                        Arcade
# 23                        Arcade
# 24                Chocolate Shop
# 25                          Park
# 26                  Dessert Shop
# 27                  Dessert Shop
# 28                History Museum
# 29                Ice Cream Shop
# ..                           ...
# 53                  Dessert Shop
# 54                 Movie Theater
# 55                    Playground
# 56                    Playground
# 57                        Arcade
# 58                        Church
# 59                          Park
# 60                  Dessert Shop
# 61                History Museum
# 62                Ice Cream Shop
# 63                Ice Cream Shop
# 64                History Museum
# 65                History Museum
# 66                History Museum
# 67                 Historic Site
# 68                History Museum
# 69                    Art Museum
# 70                Ice Cream Shop
# 71                History Museum
# 72           Government Building
# 73                    Food Court
# 74                  Cupcake Shop
# 75                Science Museum
# 76                    Restaurant
# 77                           Bar
# 78  Theme Park Ride / Attraction
# 79             Food & Drink Shop
# 80            Frozen Yogurt Shop
# 81                      Pie Shop
# 82                      Pie Shop
#
#                                                 items        lat        lng
# 0   [{'summary': 'This spot is popular', 'type': '...  55.760178  37.624539
# 1   [{'summary': 'This spot is popular', 'type': '...  55.759787  37.624449
# 2   [{'summary': 'This spot is popular', 'type': '...  55.764167  37.628912
# 3   [{'summary': 'This spot is popular', 'type': '...  55.760263  37.624862
# 4   [{'summary': 'This spot is popular', 'type': '...  55.760277  37.625998
# 5   [{'summary': 'This spot is popular', 'type': '...  55.760761  37.623263
# 6   [{'summary': 'This spot is popular', 'type': '...  55.758951  37.625089
# 7   [{'summary': 'This spot is popular', 'type': '...  55.758790  37.636062
# 8   [{'summary': 'This spot is popular', 'type': '...  55.757385  37.633633
# 9   [{'summary': 'This spot is popular', 'type': '...  55.764758  37.631597
# 10  [{'summary': 'This spot is popular', 'type': '...  55.756052  37.636124
# 11  [{'summary': 'This spot is popular', 'type': '...  55.755622  37.620072
# 12  [{'summary': 'This spot is popular', 'type': '...  55.754987  37.633627
# 13  [{'summary': 'This spot is popular', 'type': '...  55.761801  37.614409
# 14  [{'summary': 'This spot is popular', 'type': '...  55.767597  37.631584
# 15  [{'summary': 'This spot is popular', 'type': '...  55.758788  37.629050
# 16  [{'summary': 'This spot is popular', 'type': '...  55.757883  37.618379
# 17  [{'summary': 'This spot is popular', 'type': '...  55.755186  37.638971
# 18  [{'summary': 'This spot is popular', 'type': '...  55.762958  37.636004
# 19  [{'summary': 'This spot is popular', 'type': '...  55.765204  37.616348
# 20  [{'summary': 'This spot is popular', 'type': '...  55.760141  37.624925
# 21  [{'summary': 'This spot is popular', 'type': '...  55.754805  37.621805
# 22  [{'summary': 'This spot is popular', 'type': '...  55.761636  37.612162
# 23  [{'summary': 'This spot is popular', 'type': '...  55.757329  37.628527
# 24  [{'summary': 'This spot is popular', 'type': '...  55.767981  37.622808
# 25  [{'summary': 'This spot is popular', 'type': '...  55.768278  37.623807
# 26  [{'summary': 'This spot is popular', 'type': '...  55.755622  37.619935
# 27  [{'summary': 'This spot is popular', 'type': '...  55.760791  37.622971
# 28  [{'summary': 'This spot is popular', 'type': '...  55.760818  37.635512
# 29  [{'summary': 'This spot is popular', 'type': '...  55.756540  37.632492
# ..                                                ...        ...        ...
# 53  [{'summary': 'This spot is popular', 'type': '...  55.766868  37.623480
# 54  [{'summary': 'This spot is popular', 'type': '...  55.756220  37.615481
# 55  [{'summary': 'This spot is popular', 'type': '...  55.758782  37.641531
# 56  [{'summary': 'This spot is popular', 'type': '...  55.763226  37.641330
# 57  [{'summary': 'This spot is popular', 'type': '...  55.761626  37.612249
# 58  [{'summary': 'This spot is popular', 'type': '...  55.752524  37.623110
# 59  [{'summary': 'This spot is popular', 'type': '...  55.751669  37.626524
# 60  [{'summary': 'This spot is popular', 'type': '...  55.753987  37.635727
# 61  [{'summary': 'This spot is popular', 'type': '...  55.752247  37.627006
# 62  [{'summary': 'This spot is popular', 'type': '...  55.758143  37.612880
# 63  [{'summary': 'This spot is popular', 'type': '...  55.757015  37.616459
# 64  [{'summary': 'This spot is popular', 'type': '...  55.756382  37.617188
# 65  [{'summary': 'This spot is popular', 'type': '...  55.756703  37.618390
# 66  [{'summary': 'This spot is popular', 'type': '...  55.756542  37.636396
# 67  [{'summary': 'This spot is popular', 'type': '...  55.760333  37.640118
# 68  [{'summary': 'This spot is popular', 'type': '...  55.755801  37.618856
# 69  [{'summary': 'This spot is popular', 'type': '...  55.762358  37.628307
# 70  [{'summary': 'This spot is popular', 'type': '...  55.766756  37.623938
# 71  [{'summary': 'This spot is popular', 'type': '...  55.757991  37.641706
# 72  [{'summary': 'This spot is popular', 'type': '...  55.760069  37.640060
# 73  [{'summary': 'This spot is popular', 'type': '...  55.762043  37.623765
# 74  [{'summary': 'This spot is popular', 'type': '...  55.760211  37.614021
# 75  [{'summary': 'This spot is popular', 'type': '...  55.758006  37.629188
# 76  [{'summary': 'This spot is popular', 'type': '...  55.761737  37.618491
# 77  [{'summary': 'This spot is popular', 'type': '...  55.766538  37.630221
# 78  [{'summary': 'This spot is popular', 'type': '...  55.751499  37.627144
# 79  [{'summary': 'This spot is popular', 'type': '...  55.757791  37.635561
# 80  [{'summary': 'This spot is popular', 'type': '...  55.756237  37.615452
# 81  [{'summary': 'This spot is popular', 'type': '...  55.766343  37.630634
# 82  [{'summary': 'This spot is popular', 'type': '...  55.757983  37.633365
#
# [83 rows x 6 columns]
